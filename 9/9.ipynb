# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откроем-файлы-и-изучим-их" data-toc-modified-id="Откроем-файлы-и-изучим-их-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Откроем файлы и изучим их</a></span></li><li><span><a href="#Проведём-предобработку-данных" data-toc-modified-id="Проведём-предобработку-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проведём предобработку данных</a></span></li><li><span><a href="#Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Вычислиv-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдём-MAE-между-нашими-расчётами-и-значением-признака" data-toc-modified-id="Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Вычислиv-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдём-MAE-между-нашими-расчётами-и-значением-признака-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверим, что эффективность обогащения рассчитана правильно. Вычислиv её на обучающей выборке для признака rougher.output.recovery. Найдём MAE между нашими расчётами и значением признака</a></span></li><li><span><a href="#Проанализируем-признаки,-недоступные-в-тестовой-выборке.-Посмотрим-что-это-за-параметры" data-toc-modified-id="Проанализируем-признаки,-недоступные-в-тестовой-выборке.-Посмотрим-что-это-за-параметры-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проанализируем признаки, недоступные в тестовой выборке. Посмотрим что это за параметры</a></span></li><li><span><a href="#Краткий-вывод-по-первому-шагу." data-toc-modified-id="Краткий-вывод-по-первому-шагу.-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Краткий вывод по первому шагу.</a></span></li></ul></li><li><span><a href="#Проанализируем-данные" data-toc-modified-id="Проанализируем-данные-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Проанализируем данные</a></span><ul class="toc-item"><li><span><a href="#Построим-визуалицаю-по-количеству-свинца/соли/серебра-и-наконец-золота-в-зависимости-от-этапа" data-toc-modified-id="Построим-визуалицаю-по-количеству-свинца/соли/серебра-и-наконец-золота-в-зависимости-от-этапа-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Построим визуалицаю по количеству свинца/соли/серебра и наконец золота в зависимости от этапа</a></span></li><li><span><a href="#(Дополнительно)-Посмотрим-начальные-концентрации-металла" data-toc-modified-id="(Дополнительно)-Посмотрим-начальные-концентрации-металла-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>(Дополнительно) Посмотрим начальные концентрации металла</a></span></li><li><span><a href="#Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li><li><span><a href="#Краткий-вывод-по-второму-шагу." data-toc-modified-id="Краткий-вывод-по-второму-шагу.-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Краткий вывод по второму шагу.</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Необходимые-параметры" data-toc-modified-id="Необходимые-параметры-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Необходимые параметры</a></span></li><li><span><a href="#Напишем-функцию-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Напишем-функцию-для-вычисления-итоговой-sMAPE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Напишем функцию для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Разобъем-обучаюущую-выборку" data-toc-modified-id="Разобъем-обучаюущую-выборку-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Разобъем обучаюущую выборку</a></span></li><li><span><a href="#Обучим-разные-модели" data-toc-modified-id="Обучим-разные-модели-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Обучим разные модели</a></span><ul class="toc-item"><li><span><a href="#Подберем-гиперпараметры-для-моделей" data-toc-modified-id="Подберем-гиперпараметры-для-моделей-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Подберем гиперпараметры для моделей</a></span><ul class="toc-item"><li><span><a href="#rougher.output.recovery" data-toc-modified-id="rougher.output.recovery-3.4.1.1"><span class="toc-item-num">3.4.1.1&nbsp;&nbsp;</span>rougher.output.recovery</a></span></li><li><span><a href="#final.output.recovery" data-toc-modified-id="final.output.recovery-3.4.1.2"><span class="toc-item-num">3.4.1.2&nbsp;&nbsp;</span>final.output.recovery</a></span></li></ul></li><li><span><a href="#обучим-модели" data-toc-modified-id="обучим-модели-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>обучим модели</a></span></li></ul></li><li><span><a href="#проверим-модели-на-тесте" data-toc-modified-id="проверим-модели-на-тесте-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>проверим модели на тесте</a></span></li><li><span><a href="#DummyRegressor" data-toc-modified-id="DummyRegressor-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>DummyRegressor</a></span></li><li><span><a href="#Краткий-вывод-по-третьему-шагу." data-toc-modified-id="Краткий-вывод-по-третьему-шагу.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Краткий вывод по третьему шагу.</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# <b>Технологический процесс</b>
#
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
# ![2.jpg](attachment:2.jpg)
#
# Опишем каждую стадию:
# 1. Флотация
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
# 2. Очистка
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# <b>Описание данных</b>
#
# _Технологический процесс_
#
# * Rougher feed — исходное сырье
# *	Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# **	Xanthate **— ксантогенат (промотер, или активатор флотации);
# **	Sulphate — сульфат (на данном производстве сульфид натрия);
# **	Depressant — депрессант (силикат натрия).
# *	Rougher process (англ. «грубый процесс») — флотация
# *	Rougher tails — отвальные хвосты
# *	Float banks — флотационная установка
# *	Cleaner process — очистка
# *	Rougher Au — черновой концентрат золота
# *	Final Au — финальный концентрат золота
#
# _Параметры этапов_
#
# * air amount — объём воздуха
# * fluid levels — уровень жидкости
# * feed size — размер гранул сырья
# * feed rate — скорость подачи
#
# _Наименование признаков_
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# * rougher — флотация
# * primary_cleaner — первичная очистка
# * secondary_cleaner — вторичная очистка
# * final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# * input — параметры сырья
# * output — параметры продукта
# * state — параметры, характеризующие текущее состояние этапа
# * calculation — расчётные характеристики

# %% [markdown]
# <b>Расчёт эффективности</b>
#
#
# Нужно смоделировать процесс восстановления золота из золотосодержащей руды.
# Эффективность обогащения рассчитывается по формуле![1.jpg](attachment:1.jpg)
#
# где:
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# <b>Метрика качества</b>
#
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# Метрика sMAPE вычисляется так:![3.jpg](attachment:3.jpg)

# %% [markdown]
# Нужно спрогнозировать сразу две величины:
# 1.	эффективность обогащения чернового концентрата rougher.output.recovery;
# 2.	эффективность обогащения финального концентрата final.output.recovery.
# Итоговая метрика складывается из двух величин
# ![4.jpg](attachment:4.jpg)

# %% [markdown]
# <b>Описание проекта</b>
#
# Данные находятся в трёх файлах:
# * gold_recovery_train_new.csv — обучающая выборка;
# * gold_recovery_test_new.csv — тестовая выборка;
# * gold_recovery_full_new.csv — исходные данные.
# Данные индексируются датой и временем получения информации (признак date).
#
# Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей.
#
# Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В нашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, нам необходимо проверить их на корректность.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# [Сразу к выводу](#section_id1)
#
# <b> Импортируем нелобходимые библиотеки</b>

# %%
import pandas as pd
import numpy as np
from numpy.random import RandomState
from numpy.random import RandomState
from matplotlib import pyplot as plt
from scipy import stats as st
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, KFold,cross_val_score
from sklearn.metrics import mean_squared_error,mean_absolute_error,make_scorer,accuracy_score
from sklearn.linear_model import LinearRegression,LogisticRegression 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 
from sklearn.preprocessing import StandardScaler
from sklearn.multioutput import MultiOutputClassifier
from sklearn.dummy import DummyRegressor

# %% [markdown]
# <b>Откроем наши файлы с данными<b/>

# %%
try:
    df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
except:
    df_train = pd.read_csv('gold_recovery_train_new.csv')

# %%
try:
    df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
except:
    df_test = pd.read_csv('gold_recovery_test_new.csv')

# %%
try:
    df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
except:
    df_full = pd.read_csv('gold_recovery_full_new.csv')

# %% [markdown]
# Я конкретно запутался в задании и для объяснения себе нарисовал вот такую табличку, ссылаться на неё далее я нигде не буду, но по-моему она достаточно ёмко показывает всю ту информацию что есть в дф
# ![%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82.png](attachment:%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82.png)

# %% [markdown]
# ### Откроем файлы и изучим их
# <b>Откроем файлы и изучим их<b/>

# %%
#Данная функция даёт нам заголовок датафрейма, понадобится далее
def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name

# %%
dfs = [df_train, df_test, df_full]
for df in dfs:
    print('Название датафрейма: ',get_df_name(df))
    display(df.info())
    display(df.head(5))
    display('Количество явных дубликтов:', df.duplicated().sum())
    print('-' * 100)
# Out:
# Название датафрейма:  df_train
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# ### Проведём предобработку данных

# %% [markdown]
# Т.к. в каждом дф есть пустые значения, то заменим их на медианные сгруппированные по всей выборке(для этого мы сделаем колонку all). Чтобы по всем 86 в ручную не делать напишем цикл.

# %%
df_train_columns = df_train.columns
for i in df_train_columns:
    if i !='date':
        df_train[i] = df_train[i].ffill()

# %%
df_test_columns = df_test.columns
for i in df_test_columns:
    if i !='date':
        df_test[i] = df_test[i].ffill()

# %%
df_full_columns = df_full.columns
for i in df_full_columns:
    if i !='date':
        df_full[i] = df_full[i].ffill()

# %% [markdown]
# ### Проверим, что эффективность обогащения рассчитана правильно. Вычислиv её на обучающей выборке для признака rougher.output.recovery. Найдём MAE между нашими расчётами и значением признака
#
#
# Итак, у нас есть rougher.output.recovery, посчитаем его сами на сырых данных. Напомним что она считается по формуле
#
# <b> С * (F - T) / F * (C - T) ,где</b>
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.

# %%
c = df_train['rougher.output.concentrate_au']
f = df_train['rougher.input.feed_au']
t = df_train['rougher.output.tail_au']
our_recovery= ((c * (f - t))/(f * (c - t)))* 100

# %% [markdown]
# Посчитаем среднюю ошибку

# %%
df_recovery = df_train['rougher.output.recovery']
display(mean_absolute_error(df_recovery,our_recovery))
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Мы можем видеть, что в приведенном выше примере было возвращено значение MAE 9.7. Это означает, что в среднем прогнозируемые значения будут отклонены на 9.7 единицы.

# %% [markdown]
# ### Проанализируем признаки, недоступные в тестовой выборке. Посмотрим что это за параметры
#
# * В df_test у нас 50 признаков в df_train и df_full 82 признака и  два целевых значения по эффективности обогащения. (date в расчёт не входит)

# %%
set(df_full.columns) - set(df_test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# В df_test у нас нет признаков output, так как это целевые признаки.
# <a id='section_id2'></a>
#
#     Во флотационной/первичной и финальной стадиях:
#
#     - доли серебра в концентрате;
#     - доли свинца в концентрате;
#     - доли соли в концентрате;
#     - доли золота в концентрате;
#
#     Во флотационной/первичной/вторичной и финальных стадиях:
#
#     - доли серебра в отвальных хвостах;
#     - доли свинца в отвальных хвостах;
#     - доли соли в отвальных хвостах;
#     - доли золота в отвальных хвостах
#
#     Во флотационной и финальной стадиях:
#     - Эффективности обогащения
#
#     И 4-х расчётных характеристик концентрата сульфата к золоту в флотационной стадии.
#
# Т.к. для будущей модели потребуется целевой признак по эффективности обогащения, то мы добавим колонки __('rougher.output.recovery' и 'final.output.recovery')__ в тестовую выборку

# %%
df_test = df_test.join(df_full.loc[df_test.index][['final.output.recovery','rougher.output.recovery']])

# %% [markdown]
# Проверим:

# %%
df_test.columns
# Out:
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
# ...

# %% [markdown]
# ### Краткий вывод по первому шагу.
# <a id='section_id1'></a>
#
# На первом шаге мы ознакомились с данными:
# * в данных отсутсвуют дубликаты
# * в данных есть пропуски (обработали медианным значением)
# * проверили эффективность обогащения. В среднем прогнозируемые значения будут отклонены на 9.7 единицы.
# * проанализировали признакми отсутсвующие в тестовой выборке. В большинстве своём это целевые признаки.
# [Подробнее](#section_id2)
#
# <b>По итогу есть три датасета. Train нужен чтобы обучить модель, test чтобы проверить, а вот full чтобы в следующем шаге по анализу данных вывести какие значения по параметрам (а их куча) норма а какие нет .</b>

# %% [markdown]
# ## Проанализируем данные
#
# [Сразу к выводу](#section_id2)

# %% [markdown]
# [за следующие красивые графики спасибо ревьюеру Даниле Тарасову за наводку на вот эту статью](https://habr.com/ru/post/468295/ "ссылка на источник")
#
# [за объяснение флотации спасибо ребятам с группы и этому видео](https://www.youtube.com/watch?v=BY9d1MC6qLs "ссылка на источник")

# %% [markdown]
# ### Построим визуалицаю по количеству свинца/соли/серебра и наконец золота в зависимости от этапа

# %%
# начнем с конца, то есть с свинца
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.kdeplot(df_train['final.output.concentrate_pb'], shade=True, color="g", label="Финальный концентрат", alpha=.7)
sns.kdeplot(df_train['primary_cleaner.output.concentrate_pb'], shade=True, color="deeppink", label="На первом этапе очистки", alpha=.7)
sns.kdeplot(df_train['rougher.output.concentrate_pb'], shade=True, color="dodgerblue", label="Флотация", alpha=.7)

# Decoration
plt.title('Плотность свинца в зависимости от этапа', fontsize=22)
plt.legend()
plt.show()

# %% [markdown]
# Свинца в конце больше чем на флотации и на первом этапе очистки

# %%
# далее идёт соль
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.kdeplot(df_train['final.output.concentrate_sol'], shade=True, color="g", label="Финальный концентрат", alpha=.7)
sns.kdeplot(df_train['primary_cleaner.output.concentrate_sol'], shade=True, color="deeppink", label="На первом этапе очистки", alpha=.7)
sns.kdeplot(df_train['rougher.output.concentrate_sol'], shade=True, color="dodgerblue", label="Флотация", alpha=.7)

# Decoration
plt.title('Плотность соли в зависимости от этапа', fontsize=22)
plt.legend()
plt.show()

# %% [markdown]
# Меньше всего соли на последнем этапе больше всего после флоатации

# %%
# посмотрим на распределение серебра
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.kdeplot(df_train['final.output.concentrate_ag'], shade=True, color="g", label="Финальный концентрат", alpha=.7)
sns.kdeplot(df_train['primary_cleaner.output.concentrate_ag'], shade=True, color="deeppink", label="На первом этапе очистки", alpha=.7)
sns.kdeplot(df_train['rougher.output.concentrate_ag'], shade=True, color="dodgerblue", label="Флотация", alpha=.7)

# Decoration
plt.title('Плотность серебра в зависимости от этапа', fontsize=22)
plt.legend()
plt.show()

# %% [markdown]
# С каждой последующей стадией плотность серебра становиться всё меньше.

# %%
# замыкаем самым главным - золотом

# Draw Plot
plt.figure(figsize=(13,10), dpi= 80)
sns.distplot(df_train['final.output.concentrate_au'].copy(), color="black", label="Финальный концентрат", hist_kws={'alpha':.7}, kde_kws={'linewidth':3})
sns.distplot(df_train['primary_cleaner.output.concentrate_au'].copy(), color="blue", label="На первом этапе очистки", hist_kws={'alpha':.7}, kde_kws={'linewidth':3})
sns.distplot(df_train['rougher.output.concentrate_au'].copy(), color="green", label="Флотация", hist_kws={'alpha':.7}, kde_kws={'linewidth':3})

#plt.ylim(0, 0.35)

# Decoration
plt.title('Плотность золота в зависимости от этапа', fontsize=22)
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Как мы видим с каждым этапом плотность золота увеличивается. Что в принципе логично.
#
# Также мы видим что на каждом этапе есть ситуации когда количество золота на нуле. Наверное такая ситуация нормальна.

# %% [markdown]
# ### (Дополнительно) Посмотрим начальные концентрации металла

# %%
# посмотрим на распределение серебра
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.kdeplot(df_train['rougher.input.feed_ag'], shade=True, color="g", label="Начальные концентрации серебра", alpha=.7)
sns.kdeplot(df_train['rougher.input.feed_pb'], shade=True, color="deeppink", label="Начальные концентрации меди", alpha=.7)
sns.kdeplot(df_train['rougher.input.feed_au'], shade=True, color="dodgerblue", label="Начальные концентрации золота", alpha=.7)
sns.kdeplot(df_train['rougher.input.feed_sol'], shade=True, color="red", label="Начальные концентрации соли", alpha=.7)

# Decoration
plt.title('Плотность металлов в начале', fontsize=22)
plt.legend()
plt.show()

# %% [markdown]
# <b>Как мы видим в начале меньше всего концентрация меди, плотность концентрации золота и серебра примерно одинакова, а соли больше всего с огромным перевесом</b>

# %% [markdown]
# ### Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.kdeplot(df_train['rougher.input.feed_size'], shade=True, color="g", label="Обучающая выборка", alpha=.7)
sns.kdeplot(df_test['rougher.input.feed_size'], shade=True, color="deeppink", label="Тестовая выборка", alpha=.7)

# Decoration
plt.title("Гистограмма распределения гранул сырья во время флотации")
plt.legend()
plt.show()

# %% [markdown]
# Распределение гранул до флотации похоже на нормальное со смещением влево как в обучающей, так и в тестовой выбрке. Существует много выбросов после размера гранул 100.

# %%
# Import Data

# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.violinplot(y='rougher.input.feed_size', data=df_train, scale='width', inner='quartile', grid=True)
#sns.violinplot(x='all', y='rougher.input.feed_size', data=df_test, scale='width', inner='quartile')

# Decoration
plt.title('Бокс-плот по тренировочной выборке по размеру гранул', fontsize=10)
plt.show()

# %% [markdown]
# Удалим выбросы по 'rougher.input.feed_size'. Под выбросом я понимаю всё значения за пределами 25% перцентили минус 1.5 х МКР и 75% перцентили плюс 1.5 х МКР

# %%
Q1 =  df_train['rougher.input.feed_size'].quantile(0.25)
Q3 = df_train['rougher.input.feed_size'].quantile(0.75)
IQR = Q3 - Q1
df_train[df_train['rougher.input.feed_size'] < 1]['rougher.input.feed_size'].count()

df_train = df_train.drop(df_train[df_train['rougher.input.feed_size'] < Q1-1.5*IQR].index)
df_train = df_train.drop(df_train[df_train['rougher.input.feed_size'] > Q3+1.5*IQR].index)

# %%
# Import Data

# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.violinplot(y='rougher.input.feed_size', data=df_train, scale='width', inner='quartile', grid=True)
#sns.violinplot(x='all', y='rougher.input.feed_size', data=df_test, scale='width', inner='quartile')

# Decoration
plt.title('Бокс-плот по тренировочной выборке по размеру гранул', fontsize=10)
plt.show()

# %%
# Import Data

# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
#sns.violinplot(x='all', y='rougher.input.feed_size', data=df_train, scale='width', inner='quartile')
sns.violinplot( y='rougher.input.feed_size', data=df_test, scale='width', inner='quartile', grid=True)

# Decoration
plt.title('Бокс-плот по тестовой выборке по размеру гранул', fontsize=10)
plt.show()

# %% [markdown]
# Сделаем также как и с обучающей выборкой

# %%
Q1 =  df_test['rougher.input.feed_size'].quantile(0.25)
Q3 = df_test['rougher.input.feed_size'].quantile(0.75)
IQR = Q3 - Q1
df_test[df_test['rougher.input.feed_size'] < 1]['rougher.input.feed_size'].count()

df_test = df_test.drop(df_test[df_test['rougher.input.feed_size'] < Q1-1.5*IQR].index)
df_test = df_test.drop(df_test[df_test['rougher.input.feed_size'] > Q3+1.5*IQR].index)

# %%
# Import Data

# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
#sns.violinplot(x='all', y='rougher.input.feed_size', data=df_train, scale='width', inner='quartile')
sns.violinplot( y='rougher.input.feed_size', data=df_test, scale='width', inner='quartile', grid=True)

# Decoration
plt.title('Бокс-плот по тестовой выборке по размеру гранул', fontsize=10)
plt.show()

# %% [markdown]
# ### Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %% [markdown]
# Посмотрим на расределение металлов в отвальных хвостах в зависимости от стадии

# %%
r_au = df_train['rougher.output.tail_au'].sum()
r_ag = df_train['rougher.output.tail_ag'].sum()
r_pb = df_train['rougher.output.tail_pb'].sum()
r_sol = df_train['rougher.output.tail_sol'].sum()

f_au = df_train['final.output.tail_au'].sum()
f_ag = df_train['final.output.tail_ag'].sum()
f_pb = df_train['final.output.tail_pb'].sum()
f_sol = df_train['final.output.tail_sol'].sum()

# %%
r_tail = np.array([r_au,r_ag,r_pb,r_sol])
r_tail = pd.Series(r_tail)

f_tail = np.array([f_au,f_ag,f_pb,f_sol])
f_tail = pd.Series(f_tail)

tail_name = np.array(['au','ag','pb','sol'])
tail_name = pd.Series(tail_name)

# %%
test = pd.concat([tail_name,r_tail,f_tail ], axis=1)

# %%
test.columns = ['name','rough', 'final']

# %%
import matplotlib.lines as mlines
# Import Data
#test = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/gdppercap.csv")

#left_label = [str(c) + ', '+ str(round(y)) for c, y in zip(test.name, test['primarly'])]
#right_label = [str(c) + ', '+ str(round(y)) for c, y in zip(test.name, test['final'])]
#klass = ['red' if (y1-y2) < 0 else 'green' for y1, y2 in zip(test['primarly'], test['final'])]

# draw line
# https://stackoverflow.com/questions/36470343/how-to-draw-a-line-with-matplotlib/36479941
def newline(p1, p2, color='black'):
    ax = plt.gca()
    l = mlines.Line2D([p1[0],p2[0]], [p1[1],p2[1]], color='red' if p1[1]-p2[1] > 0 else 'green', marker='o', markersize=6)
    ax.add_line(l)
    return l

fig, ax = plt.subplots(1,1,figsize=(10,6), dpi=80)

# Vertical Lines
ax.vlines(x=1, ymin=9000, ymax=250000, color='black', alpha=0.7, linewidth=1, linestyles='dotted')
ax.vlines(x=3, ymin=9000, ymax=250000, color='black', alpha=0.7, linewidth=1, linestyles='dotted')

# Points
ax.scatter(y=test['rough'], x=np.repeat(1, test.shape[0]), s=10, color='black', alpha=0.7)
ax.scatter(y=test['final'], x=np.repeat(3, test.shape[0]), s=10, color='black', alpha=0.7)

# Line Segmentsand Annotation
for p1, p2, c in zip(test['rough'], test['final'], test['name']):
    newline([1,p1], [3,p2])
    ax.text(1-0.05, p1, c + ', ' + str(round(p1)), horizontalalignment='right', verticalalignment='center', fontdict={'size':14})
    ax.text(3+0.05, p2, c + ', ' + str(round(p2)), horizontalalignment='left', verticalalignment='center', fontdict={'size':14})

# 'Before' and 'After' Annotations
ax.text(1-0.05, 40000, 'Флотация', horizontalalignment='right', verticalalignment='center', fontdict={'size':18, 'weight':700})
ax.text(3+0.05, 50000, 'Финальный концентрат', horizontalalignment='left', verticalalignment='center', fontdict={'size':18, 'weight':700})

# Decoration
ax.set_title("Количество разных металлов в первой стадии и последней", fontdict={'size':22})
#ax.set(xlim=(0,4), ylim=(0,14000), ylabel='Mean GDP Per Capita')
#ax.set_xticks([1,3])
#ax.set_xticklabels(["rough", "final"])
#plt.yticks(np.arange(500, 13000, 2000), fontsize=12)

# Lighten borders
plt.gca().spines["top"].set_alpha(.0)
plt.gca().spines["bottom"].set_alpha(.0)
plt.gca().spines["right"].set_alpha(.0)
plt.gca().spines["left"].set_alpha(.0)
plt.show()

# %% [markdown]
# Как мы видим из визуализации количество всех металлов в отвальных хвостах от флотации к финальному концентрату вырастает. Исключением является соль. Единственная проблема не понятно есть ли аномалии в датасете.
#
# Я не сразу правильно понял задание, залез в слак и там уже догнал что конкретно хотели, поэтому вернемся к гистограммам.

# %%
df_train_copy = df_train.copy()

# %%
final_all = (df_train_copy['final.output.concentrate_au'] + 
                                      df_train_copy['final.output.concentrate_ag'] + 
                                      df_train_copy['final.output.concentrate_pb'] +
                                      df_train_copy['final.output.concentrate_sol'])
#primary_all = (df_train_copy['primary_cleaner.output.concentrate_au'] + 
#                                                df_train_copy['primary_cleaner.output.concentrate_ag'] + 
#                                                df_train_copy['primary_cleaner.output.concentrate_pb'] +
#                                                df_train_copy['primary_cleaner.output.concentrate_sol'])
rougher_begin_all = (df_train_copy['rougher.input.feed_au'] + 
                                                df_train_copy['rougher.input.feed_ag'] + 
                                                df_train_copy['rougher.input.feed_pb'] +
                                                df_train_copy['rougher.input.feed_sol'])

rougher_all = (df_train_copy['rougher.output.concentrate_au'] + 
                                        df_train_copy['rougher.output.concentrate_ag'] + 
                                        df_train_copy['rougher.output.concentrate_pb'] +
                                        df_train_copy['rougher.output.concentrate_sol'])

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
sns.kdeplot(final_all, shade=True, color="black", label="Финальный концентрат", alpha=.7)
sns.kdeplot(rougher_begin_all, shade=True, color="yellow", label="Сырьевой концентрат", alpha=.7)
sns.kdeplot(rougher_all, shade=True, color="red", label="Черновой концентрат", alpha=.7)

# Decoration
plt.title("Гистограмма концентрации всех веществ на разных стадиях")
plt.legend()
plt.show()

# %% [markdown]
# В финальном концентрете концетрация больше всего, также отчётливо видим что на шаге флотации есть много выбросов - нулевых значений.

# %%
# Import Data

# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
#sns.violinplot(x='all', y='rougher.input.feed_size', data=df_train, scale='width', inner='quartile')
sns.violinplot( data=rougher_all, scale='width', inner='quartile', grid=True)

# Decoration
plt.title('Бокс-плот по концентрации во флотации', fontsize=10)
plt.show()

# %% [markdown]
# Тут этот выброс виден еще больше.

# %%
# сумма по всем элементам ноль даёт по этому разницы нет по чему конкретно мы удалим данные
df_train = df_train.drop(df_train[df_train['rougher.output.concentrate_au'] == 0].index)

# %% [markdown]
# ### Краткий вывод по второму шагу.
# <a id='section_id2'></a>
#
# На первом шаге мы проводили анализ данных и предобрабатывали "странные" выбивающиеся значения:
# * Плотность свинца, серебра, соли и меди постепенно с каждым шагом уменьшается, плотность же золота в финальном концентрате максимально по сравнению с отсальными стадиями.
# * Также мы заметили, что на какждом шаге есть ситуации когда определеннного металла нет. Предположив, что это более химический вопрос нежели статистический мы решили не обрабатывать эту ситуацию.
# * Сравнив распределения размеров гранул сырья на обучающей и тестовой выборках мы выявили, что в обоих случаях имеется нормальное распределение размеров.
# * Также мы увидели и предобраотали выбросы. Под выбросом были определены все значения за пределами 25% перцентили минус 1.5 х МКР и 75% перцентили плюс 1.5 х МКР
# * Исследовав суммарную концентрацию всех веществ на разных стадиях мы выявили, что концентрация всех веществ без пустых пород в финальном концентрате максимальна. Единственным исключением является соль.
# * Также мы выявили и предобработали выбросы. Удалив те значения с пустыми значениями по металлам.
#
#
#
# <a id='section_id21'></a>
# * Все данные мы предобработали на первом шаге, в данном шаге мы посмотрели на общее распределение по данным и обработали (убрали) выбросы. Всё необходимое для того, чтобы переходить к проверке на моделях нами сделано.

# %% [markdown]
# ## Модель
#
# [Сразу к выводу](#section_id3)

# %% [markdown]
# ### Необходимые параметры
#
# Для начала проверим на параметры. Удалим из тренировочной выборки те, что мешают, плюс посмотрим по корреляции какие можно выбросить.

# %%
df_train.columns
# Out:
# Index(['date', 'final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb',
#        'final.output.tail_sol', 'final.output.tail_au',
#        'primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb',
#        'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
# ...

# %%
df_test.columns
# Out:
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
# ...

# %%
print('df_train: ',len(df_train.columns))
print('df_test: ',len(df_test.columns))
# Out:
# df_train:  87
# df_test:  55

# %%
df_train_final = df_train.copy()
df_train_final.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# Удалим целевые признаки из обучающей выборки, чтобы она соответствовала тестовой. Кроме 'final.output.recovery'	и'rougher.output.recovery'.

# %%
df_train_final = df_train_final.drop([
'date','final.output.concentrate_ag',
'final.output.concentrate_pb',
'final.output.concentrate_sol',
'final.output.concentrate_au',
'final.output.tail_ag',
'final.output.tail_pb',
'final.output.tail_sol',
'final.output.tail_au',
'primary_cleaner.output.concentrate_ag',
'primary_cleaner.output.concentrate_pb',
'primary_cleaner.output.concentrate_sol',
'primary_cleaner.output.concentrate_au',
'primary_cleaner.output.tail_ag',
'primary_cleaner.output.tail_pb',
'primary_cleaner.output.tail_sol',
'primary_cleaner.output.tail_au',
'rougher.output.concentrate_ag',
'rougher.output.concentrate_pb',
'rougher.output.concentrate_sol',
'rougher.output.concentrate_au',
'rougher.output.tail_ag',
'rougher.output.tail_pb',
'rougher.output.tail_sol',
'rougher.output.tail_au',
'secondary_cleaner.output.tail_ag',
'secondary_cleaner.output.tail_pb',
'secondary_cleaner.output.tail_sol',
'secondary_cleaner.output.tail_au',
'rougher.calculation.sulfate_to_au_concentrate',
'rougher.calculation.floatbank10_sulfate_to_au_feed',
'rougher.calculation.floatbank11_sulfate_to_au_feed',
'rougher.calculation.au_pb_ratio'], axis = 1)

# %%
df_test_final = df_test.drop(['date'], axis = 1)

# %%
print('df_train_final: ',len(df_train_final.columns))
print('df_test_final: ',len(df_test_final.columns))
# Out:
# df_train_final:  54
# df_test_final:  54

# %%
df_train_final[df_train_final['final.output.recovery'].isna()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Теперь можно перейти к выбору необходимых параметров.
#
# Все параметры в модели я использовать не собираюсь т.к. из много процессор будет долго это всё обрабатывать, поэтому я позьму посмотрю корреляцию по двум целевым признакам 'final.output.recovery' и'rougher.output.recovery', после чего удалим ненужные признакми с низкой корреляцией.

# %%
plt.figure (figsize=(40,30))
sns.heatmap (df_train_final.corr(), annot=True, cmap='Blues');

# %% [markdown]
# Судя по всему отобрать нужные признакми таким способом не получится. Максимальная коррелция по признакам по
# rougher.output.recovery 0.45
# final.output.recovery 0.39
#
# Остаётся только масштабировать признаки.

# %% [markdown]
# ### Напишем функцию для вычисления итоговой sMAPE

# %%
def smape(target, predictions):
    result = np.mean (abs(target - predictions) / ((abs(target)+abs(predictions))/2)) * 100
    return result

smape_score = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# ### Разобъем обучаюущую выборку

# %%
target_rougher = df_train_final['rougher.output.recovery']
target_cleaner = df_train_final['final.output.recovery']
features = df_train_final.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

# %% [markdown]
# Разобьем на обучающую выборку и валидную.

# %%
features_train1, features_valid1, target_train1, target_valid1 = train_test_split(
    features, target_rougher, test_size=0.25, random_state=12345)

# %%
features_train2, features_valid2, target_train2, target_valid2 = train_test_split(
    features, target_cleaner, test_size=0.25, random_state=12345)

# %%
pd.options.mode.chained_assignment = None

numeric = [
       'primary_cleaner.input.sulfate',
       'primary_cleaner.input.depressant',
        'primary_cleaner.input.feed_size',
       'primary_cleaner.input.xanthate',
       'primary_cleaner.state.floatbank8_a_air',
       'primary_cleaner.state.floatbank8_a_level',
       'primary_cleaner.state.floatbank8_b_air',
       'primary_cleaner.state.floatbank8_b_level',
       'primary_cleaner.state.floatbank8_c_air',
       'primary_cleaner.state.floatbank8_c_level',
       'primary_cleaner.state.floatbank8_d_air',
       'primary_cleaner.state.floatbank8_d_level',
       'rougher.input.feed_ag',
       'rougher.input.feed_pb', 
       'rougher.input.feed_rate',
       'rougher.input.feed_size',
       'rougher.input.feed_sol',
       'rougher.input.feed_au',
       'rougher.input.floatbank10_sulfate',
       'rougher.input.floatbank10_xanthate',
       'rougher.input.floatbank11_sulfate',
       'rougher.input.floatbank11_xanthate',
       'rougher.state.floatbank10_a_air',
       'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
       'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
       'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
       'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
       'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
       'rougher.state.floatbank10_f_level',
       'secondary_cleaner.state.floatbank2_a_air',
       'secondary_cleaner.state.floatbank2_a_level',
       'secondary_cleaner.state.floatbank2_b_air',
       'secondary_cleaner.state.floatbank2_b_level',
       'secondary_cleaner.state.floatbank3_a_air',
       'secondary_cleaner.state.floatbank3_a_level',
       'secondary_cleaner.state.floatbank3_b_air',
       'secondary_cleaner.state.floatbank3_b_level',
       'secondary_cleaner.state.floatbank4_a_air',
       'secondary_cleaner.state.floatbank4_a_level',
       'secondary_cleaner.state.floatbank4_b_air',
       'secondary_cleaner.state.floatbank4_b_level',
       'secondary_cleaner.state.floatbank5_a_air',
       'secondary_cleaner.state.floatbank5_a_level',
       'secondary_cleaner.state.floatbank5_b_air',
       'secondary_cleaner.state.floatbank5_b_level',
       'secondary_cleaner.state.floatbank6_a_air',
       'secondary_cleaner.state.floatbank6_a_level']

scaler = StandardScaler()
scaler.fit(features_train1[numeric])
scaler.fit(features_train2[numeric])
features_train1[numeric] = scaler.transform(features_train1[numeric])
features_train2[numeric] = scaler.transform(features_train2[numeric])

features_valid1[numeric]  = scaler.transform(features_valid1[numeric])
features_valid2[numeric]  = scaler.transform(features_valid2[numeric])

# %% [markdown]
# ### Обучим разные модели

# %% [markdown]
# #### Подберем гиперпараметры для моделей

# %% [markdown]
# Перед нами стоит задача регресии.
# Мы будем использовать следующие модели:
# * Линейная регрессия;
# * дерево решений;
# * случайный лес.

# %% [markdown]
# <b>
# Попробуем использовать GreedSeacrhCV
# </b>

# %% [markdown]
# ##### rougher.output.recovery

# %%
# %%time
state = 12345
cv = KFold()
model = RandomForestRegressor(random_state=12345)
    

param_dict = {'max_depth': range(1, 8),
             'n_estimators' : [5, 10, 20, 50],
              'min_samples_leaf' : range (1,6),
              'max_features' : range(1,7)}

grid = GridSearchCV(model, param_dict, cv = cv, scoring=smape_score, n_jobs = -1)

grid.fit(features_train1, target_train1)
grid.best_score_
# Out:
# CPU times: user 11min 54s, sys: 1.72 s, total: 11min 56s
# Wall time: 11min 58s
# -3.8459089888996814

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Подбор гиперпараметров проведён верно.</font>

# %% [markdown]
# Эта штука работает 15 минут (запускать на свой страх и риск)

# %%
print(grid.best_estimator_)
print()
print(grid.best_params_)
print()
print(grid.best_score_)
# Out:
# RandomForestRegressor(max_depth=7, max_features=6, min_samples_leaf=5,
#                       n_estimators=50, random_state=12345)
#
# {'max_depth': 7, 'max_features': 6, 'min_samples_leaf': 5, 'n_estimators': 50}
#
# -3.8459089888996814

# %%
# %%time
state = 12345
cv = KFold()
model = DecisionTreeRegressor(random_state=12345)
    

param_dict = {'max_depth': range(1, 8),
              'min_samples_leaf' : range (1,6),
              'max_features' : range(1,7)}

griddtr = GridSearchCV(model, param_dict, cv = cv, scoring=smape_score, n_jobs = -1)

griddtr.fit(features_train1, target_train1)
griddtr.best_score_
# Out:
# CPU times: user 18.6 s, sys: 71.7 ms, total: 18.6 s
# Wall time: 18.9 s
# -4.443582113397904

# %%
print(griddtr.best_estimator_)
print()
print(griddtr.best_params_)
print()
print(griddtr.best_score_)
# Out:
# DecisionTreeRegressor(max_depth=7, max_features=5, min_samples_leaf=2,
#                       random_state=12345)
#
# {'max_depth': 7, 'max_features': 5, 'min_samples_leaf': 2}
#
# -4.443582113397904

# %%
# %%time
state = 12345
cv = KFold()
model = LinearRegression()
    

param_dict = {'fit_intercept':[True, False],
                    'copy_X':[True, False]}

griddlr = GridSearchCV(model, param_dict, cv = cv, scoring=smape_score, n_jobs = -1)
griddlr.fit(features_train1, target_train1)
griddlr.best_score_
# Out:
# CPU times: user 3.24 s, sys: 3.55 s, total: 6.78 s
# Wall time: 6.73 s
# -4.679172075453373

# %%
# %%time
print(griddlr.best_estimator_)
print()
print(griddlr.best_params_)
print()
print(griddlr.best_score_)
# Out:
# LinearRegression()
#
# {'copy_X': True, 'fit_intercept': True}
#
# -4.679172075453373
# CPU times: user 0 ns, sys: 1.15 ms, total: 1.15 ms
# Wall time: 983 µs

# %% [markdown]
# ##### final.output.recovery

# %%
# %%time
state = 12345
cv = KFold()
model = RandomForestRegressor(random_state=12345)
    

param_dict = {'max_depth': range(1, 8),
             'n_estimators' : [5, 10, 20, 50],
              'min_samples_leaf' : range (1,6),
              'max_features' : range(1,7)}

grid2 = GridSearchCV(model, param_dict, cv = cv, scoring=smape_score, n_jobs = -1)

grid2.fit(features_train2, target_train2)
grid2.best_score_
# Out:
# CPU times: user 12min 7s, sys: 2.46 s, total: 12min 10s
# Wall time: 12min 10s
# -7.925200925318826

# %%
print(grid2.best_estimator_)
print()
print(grid2.best_params_)
print()
print(grid2.best_score_)
# Out:
# RandomForestRegressor(max_depth=7, max_features=6, min_samples_leaf=5,
#                       n_estimators=50, random_state=12345)
#
# {'max_depth': 7, 'max_features': 6, 'min_samples_leaf': 5, 'n_estimators': 50}
#
# -7.925200925318826

# %%
# %%time
state = 12345
cv = KFold()
model = DecisionTreeRegressor(random_state=12345)
    

param_dict = {'max_depth': range(1, 8),
              'min_samples_leaf' : range (1,6),
              'max_features' : range(1,7)}

griddtr2 = GridSearchCV(model, param_dict, cv = cv, scoring=smape_score, n_jobs = -1)

griddtr2.fit(features_train2, target_train2)
griddtr2.best_score_
# Out:
# CPU times: user 18.5 s, sys: 27.9 ms, total: 18.6 s
# Wall time: 18.6 s
# -8.823084038765803

# %%
print(griddtr2.best_estimator_)
print()
print(griddtr2.best_params_)
print()
print(griddtr2.best_score_)
# Out:
# DecisionTreeRegressor(max_depth=7, max_features=5, random_state=12345)
#
# {'max_depth': 7, 'max_features': 5, 'min_samples_leaf': 1}
#
# -8.823084038765803

# %%
# %%time
state = 12345
cv = KFold()
model = LinearRegression()
    

param_dict = {'fit_intercept':[True, False],
                    'copy_X':[True, False]}

griddlr2 = GridSearchCV(model, param_dict, cv = cv, scoring=smape_score, n_jobs = -1)
griddlr2.fit(features_train2, target_train2)
griddlr2.best_score_
# Out:
# CPU times: user 2.87 s, sys: 3 s, total: 5.87 s
# Wall time: 5.81 s
# -8.887509612897873

# %%
print(griddlr2.best_estimator_)
print()
print(griddlr2.best_params_)
print()
print(griddlr2.best_score_)
# Out:
# LinearRegression()
#
# {'copy_X': True, 'fit_intercept': True}
#
# -8.887509612897873

# %% [markdown]
# #### обучим модели

# %% [markdown]
# <b>rougher.output.recovery</b>

# %%
model1 = RandomForestRegressor(random_state=12345,
                               max_depth=7,
                               max_features=6,
                               min_samples_leaf=5,
                               n_estimators=50) 
model1.fit(features_train1, target_train1) 
predictions_1 = model1.predict(features_valid1) # получим предсказания модели
result1 = smape(target_valid1,predictions_1)


print("rougher.output.recovery(RandomForestRegressor): ", result1)
# Out:
# rougher.output.recovery(RandomForestRegressor):  3.7030133509709575

# %%
model2 = DecisionTreeRegressor(random_state=12345,
                               max_depth =7, 
                               max_features=5,
                               min_samples_leaf=2) 
model2.fit(features_train1, target_train1) 
predictions_2 = model2.predict(features_valid1) # получим предсказания модели
result2 = smape(target_valid1,predictions_2)


print("rougher.output.recovery(DecisionTreeRegressor): ", result2)
# Out:
# rougher.output.recovery(DecisionTreeRegressor):  4.55923765095189

# %%
model3 = LinearRegression(copy_X = True,
                          fit_intercept = True) 
model3.fit(features_train1, target_train1) 
predictions_3 = model3.predict(features_valid1) # получим предсказания модели
result3 = smape(target_valid1,predictions_3)


print("rougher.output.recovery(LinearRegression): ", result3)
# Out:
# rougher.output.recovery(LinearRegression):  4.565250900102258

# %% [markdown]
# <b>final.output.recovery</b>

# %%
model4 = RandomForestRegressor(random_state=12345,
                               max_depth=7,
                               max_features=6,
                               min_samples_leaf=5,
                               n_estimators=50) 
model4.fit(features_train2, target_train2) 
predictions_4 = model4.predict(features_valid2) # получим предсказания модели
result4 = smape(target_valid2,predictions_4)


print("final.output.recovery(RandomForestRegressor): ", result4)
# Out:
# final.output.recovery(RandomForestRegressor):  8.049874482552893

# %%
model5 = DecisionTreeRegressor(random_state=12345,
                               max_depth=7,
                               max_features=5,
                               min_samples_leaf=1) 
model5.fit(features_train2, target_train2) 
predictions_5 = model5.predict(features_valid2) # получим предсказания модели
result5 = smape(target_valid2,predictions_5)

print("final.output.recovery(DecisionTreeRegressor) ", result5)
# Out:
# final.output.recovery(DecisionTreeRegressor)  9.274264732723797

# %%
model6 = LinearRegression(copy_X = True,
                          fit_intercept = True) 
model6.fit(features_train2, target_train2) 
predictions_6 = model6.predict(features_valid2) # получим предсказания модели
result6 = smape(target_valid2,predictions_6)


print("final.output.recovery(LinearRegression): ", result6)
# Out:
# final.output.recovery(LinearRegression):  9.078470335664765

# %% [markdown]
# Значения вполне себе. Выберем <b>лучшую</b> модель.

# %%
print('RandomForestRegressor: ', result1 * 0.25 + result4 * 0.75)
print('DecisionTreeRegressor: ', result2 * 0.25 + result5 * 0.75)
print('LinearRegression: ', result3 * 0.25 + result6 * 0.75)
# Out:
# RandomForestRegressor:  6.963159199657408
# DecisionTreeRegressor:  8.09550796228082
# LinearRegression:  7.9501654767741385

# %% [markdown]
# Предварительно лучшая модель это дерево решений.

# %% [markdown]
# ### проверим модели на тесте

# %%
train_target_rougher = df_train_final['rougher.output.recovery']
train_target_cleaner = df_train_final['final.output.recovery']
train_features = df_train_final.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

test_target_rougher = df_test_final['rougher.output.recovery']
test_target_cleaner = df_test_final['final.output.recovery']
test_features = df_test_final.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

# %%
model = RandomForestRegressor(random_state=12345,
                               max_depth=7,
                               max_features=6,
                               min_samples_leaf=5,
                               n_estimators=50)
model.fit(train_features, train_target_rougher)
rougher_recovery_predicted = model.predict(test_features)
resultrfrr = smape(test_target_rougher,rougher_recovery_predicted)


model.fit(train_features, train_target_cleaner)
final_recovery_predicted = model.predict(test_features)
resultrfrc = smape(test_target_cleaner,final_recovery_predicted)

print('Итоговое sMAPE',0.25 * resultrfrr + 0.75* resultrfrc)
# Out:
# Итоговое sMAPE 11.251395321543129

# %%
model2 = DecisionTreeRegressor(random_state=12345,
                               max_depth=7,
                               max_features=5,
                               min_samples_leaf=2)
model2.fit(train_features, train_target_rougher)
rougher_recovery_predicted = model2.predict(test_features)
resultdtrr = smape(test_target_rougher,rougher_recovery_predicted)


model2.fit(train_features, train_target_cleaner)
final_recovery_predicted = model2.predict(test_features)
resultdtrc = smape(test_target_cleaner,final_recovery_predicted)

print('Итоговое sMAPE',0.25 * resultdtrr + 0.75* resultdtrc)
# Out:
# Итоговое sMAPE 12.068019159015556

# %%
model3 = LinearRegression(copy_X = True,
                          fit_intercept = True)

model3.fit(train_features, train_target_rougher)
rougher_recovery_predicted = model3.predict(test_features)
resultlrr = smape(test_target_rougher,rougher_recovery_predicted)


model3.fit(train_features, train_target_cleaner)
final_recovery_predicted = model3.predict(test_features)
resultlrc = smape(test_target_cleaner,final_recovery_predicted)

print('Итоговое sMAPE',0.25 * resultlrr + 0.75* resultlrc)
# Out:
# Итоговое sMAPE 13.063969321118353

# %% [markdown]
# А вот по результатам проверки на тестовых даных лучший результат __у линейной регрессии__.

# %% [markdown]
# ### DummyRegressor

# %%
model_dummy = DummyRegressor('mean')
model_dummy.fit(train_features, train_target_rougher)
rougher_recovery_predicted = model_dummy.predict(test_features)
result_model_dummy_r = smape(test_target_rougher,rougher_recovery_predicted)

model_dummy.fit(train_features, train_target_cleaner)
final_recovery_predicted = model_dummy.predict(test_features)
result_model_dummy_c = smape(test_target_cleaner,final_recovery_predicted)

print('Итоговое sMAPE',0.25 * result_model_dummy_r + 0.75* result_model_dummy_c)
# Out:
# Итоговое sMAPE 10.916033367076174
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass strategy=mean as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
model_dummy = DummyRegressor('median')
model_dummy.fit(train_features, train_target_rougher)
rougher_recovery_predicted = model_dummy.predict(test_features)
result_model_dummy_r = smape(test_target_rougher,rougher_recovery_predicted)

model_dummy.fit(train_features, train_target_cleaner)
final_recovery_predicted = model_dummy.predict(test_features)
result_model_dummy_c = smape(test_target_cleaner,final_recovery_predicted)

print('Итоговое sMAPE',0.25 * result_model_dummy_r + 0.75* result_model_dummy_c)
# Out:
# Итоговое sMAPE 11.186158654645382
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass strategy=median as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
model_dummy = DummyRegressor(constant=1)
model_dummy.fit(train_features, train_target_rougher)
rougher_recovery_predicted = model_dummy.predict(test_features)
result_model_dummy_r = smape(test_target_rougher,rougher_recovery_predicted)

model_dummy.fit(train_features, train_target_cleaner)
final_recovery_predicted = model_dummy.predict(test_features)
result_model_dummy_c = smape(test_target_cleaner,final_recovery_predicted)

print('Итоговое sMAPE',0.25 * result_model_dummy_r + 0.75* result_model_dummy_c)
# Out:
# Итоговое sMAPE 10.916033367076174

# %% [markdown]
# Проверили насколько результат лучше фиктивной модели при помощи DummyRegressor.
#
# В DummyRegressor использовали три стратегии:
#
# * среднее - всегда предсказывает среднее значение по дф
# * медианное - всегда предсказывает медианное значение по дф
# * константа - всегда предсказывает константу (указали что её значение равно 1) (брал с потолка)
#
# Ближе всего к нашим моделям подобралась медианная стратегия, но к значениям даже худшей модели (случайного) леса она не перебила.

# %% [markdown]
# ### Краткий вывод по третьему шагу.
# <a id='section_id3'></a>
#
# * на первом этапе мы предобработали обучающую выборку по типу тестовой убрав из неё ненужные признаки
# * попытавшись выбрать методом корреляции самые нужные признаки мы выявили, что так сделать нельзя и остановились на машстабировании признаков
# * также мы написали функцию для подсчёта smape, которую активно использовали и при обучении и при тестировании модели
# * выбрав три модели сначала мы разбили обучающую выборку на тренировочную и валидную, после использовав GreedSeacrhCV мы подобрали оптимальные гиперпараметры
# * обучив модели мы выявили, что лучший результат у модели дерева решений - 7.72
# * на заключительном этапе мы провериил наши модели на тестовых данных. По результатам данного эксперимента лучшие значения по итоговому smape получила линейная регрессия.
#
#
# *  также провериили модель на адекватность при помощи DummyRegressor. Стратегия DummyRegressor не перебила значения лучшей модели - Логистической регрессии.

# %% [markdown]
# [Про ассиметрию - смещение распределения.](https://stepik.org/lesson/613340/step/1?unit=608737)
