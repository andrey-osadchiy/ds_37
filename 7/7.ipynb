# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Кодирование-признаков" data-toc-modified-id="Кодирование-признаков-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Кодирование признаков</a></span></li><li><span><a href="#Выборки-(обучающая,-тестовая,-валидная)" data-toc-modified-id="Выборки-(обучающая,-тестовая,-валидная)-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Выборки (обучающая, тестовая, валидная)</a></span></li><li><span><a href="#Масштабирование" data-toc-modified-id="Масштабирование-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Масштабирование</a></span></li><li><span><a href="#Краткий-вывод-по-первому-шагу." data-toc-modified-id="Краткий-вывод-по-первому-шагу.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Краткий вывод по первому шагу.</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений-в-регрессии." data-toc-modified-id="Дерево-решений-в-регрессии.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Дерево решений в регрессии.</a></span></li><li><span><a href="#Случайный-лес-в-регрессии." data-toc-modified-id="Случайный-лес-в-регрессии.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Случайный лес в регрессии.</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#DummyClassifier" data-toc-modified-id="DummyClassifier-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>DummyClassifier</a></span></li><li><span><a href="#Матрица-ошибок,-плотность,-точность,-F1-score,-roc_auc" data-toc-modified-id="Матрица-ошибок,-плотность,-точность,-F1-score,-roc_auc-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Матрица ошибок, плотность, точность, F1 score, roc_auc</a></span></li><li><span><a href="#Краткий-вывод-по-второму-шагу." data-toc-modified-id="Краткий-вывод-по-второму-шагу.-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Краткий вывод по второму шагу.</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#взвешивание-классов" data-toc-modified-id="взвешивание-классов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений-в-регрессии." data-toc-modified-id="Дерево-решений-в-регрессии.-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Дерево решений в регрессии.</a></span></li><li><span><a href="#Случайный-лес-в-регрессии." data-toc-modified-id="Случайный-лес-в-регрессии.-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Случайный лес в регрессии.</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увеличение выборки</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений-в-регрессии." data-toc-modified-id="Дерево-решений-в-регрессии.-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Дерево решений в регрессии.</a></span></li><li><span><a href="#Случайный-лес-в-регрессии." data-toc-modified-id="Случайный-лес-в-регрессии.-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Случайный лес в регрессии.</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Уменьшение выборки</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений-в-регрессии." data-toc-modified-id="Дерево-решений-в-регрессии.-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Дерево решений в регрессии.</a></span></li><li><span><a href="#Случайный-лес-в-регрессии." data-toc-modified-id="Случайный-лес-в-регрессии.-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Случайный лес в регрессии.</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li></ul></li><li><span><a href="#Краткий-вывод-по-третьему-шагу." data-toc-modified-id="Краткий-вывод-по-третьему-шагу.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Краткий вывод по третьему шагу.</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Дерево-решений-в-регрессии." data-toc-modified-id="Дерево-решений-в-регрессии.-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Дерево решений в регрессии.</a></span></li><li><span><a href="#Случайный-лес-в-регрессии." data-toc-modified-id="Случайный-лес-в-регрессии.-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Случайный лес в регрессии.</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Проверяем-лучшую-модель" data-toc-modified-id="Проверяем-лучшую-модель-4.0.4"><span class="toc-item-num">4.0.4&nbsp;&nbsp;</span>Проверяем лучшую модель</a></span></li></ul></li><li><span><a href="#Краткий-вывод-по-четвертому-шагу." data-toc-modified-id="Краткий-вывод-по-четвертому-шагу.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Краткий вывод по четвертому шагу.</a></span></li><li><span><a href="#Вывод-2" data-toc-modified-id="Вывод-2-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Вывод 2</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# [Сразу к выводу](#section_id1)
#
# <b>Импортируем необходимые библиотеки</b>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier  
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score,precision_recall_curve ,f1_score, roc_auc_score,roc_curve
from sklearn.utils import shuffle
from sklearn.dummy import DummyClassifier

# %% [markdown]
# <b>Открываем файл с данными и изучаем общую информацию</b>

# %%
try:
    df = pd.read_csv('/datasets/Churn.csv')
except:
    df = pd.read_csv('Churn.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Как мы видим присутствуют пустые значения по полю "Tenure"

# %% [markdown]
# **Таблица Churn - отток клиентов**
#
# - RowNumber — индекс строки в данных
# - CustomerId — уникальный идентификатор клиента
# - Surname — фамилия
# - CreditScore — кредитный рейтинг
# - Geography — страна проживания
# - Gender — пол
# - Age — возраст
# - Tenure — сколько лет человек является клиентом банка
# - Balance — баланс на счёте
# - NumOfProducts — количество продуктов банка, используемых клиентом
# - HasCrCard — наличие кредитной карты
# - IsActiveMember — активность клиента
# - EstimatedSalary — предполагаемая зарплата
# - Exited — ушел или остался

# %% [markdown]
# Посмотрим есть ли явные дубликаты в таблице

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <b> Посмотрим корреляцию</b>

# %%
df[['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']].corr()
# Out:
#                  CustomerId  CreditScore       Age    Tenure   Balance  \
# CustomerId         1.000000     0.005308  0.009497 -0.021418 -0.012419
# CreditScore        0.005308     1.000000 -0.003965 -0.000062  0.006268
# Age                0.009497    -0.003965  1.000000 -0.013134  0.028308
# Tenure            -0.021418    -0.000062 -0.013134  1.000000 -0.007911
# Balance           -0.012419     0.006268  0.028308 -0.007911  1.000000
# EstimatedSalary    0.015271    -0.001384 -0.007201  0.010520  0.012797
#
#                  EstimatedSalary
# CustomerId              0.015271
# CreditScore            -0.001384
# Age                    -0.007201
# Tenure                  0.010520
# Balance                 0.012797
# EstimatedSalary         1.000000

# %%
sns.pairplot(df, vars = ['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary'])

# %% [markdown]
# Мультиколлениарность между признаками не наблюдается и вообще корреляция по признакам очень слабая.

# %% [markdown]
# Удаленим ненужные столбцы

# %%
df = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# %% [markdown]
# Т.к. ранее мы увидели, что есть пустые значения, то заполним их медианным значением.
# <a id='section_id10'></a>

# %%
df['Tenure'] = df['Tenure'].fillna(df['Tenure'].median()).astype('int64')

# %% [markdown]
# ### Кодирование признаков
# <a id='section_id11'></a>
# Закодируем категориальные признаки, чтобы не попасть в дамми-ловушку, применим аргумент drop_first функции pd.get_dummies()

# %%
df_ohe = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# ### Выборки (обучающая, тестовая, валидная)
# <a id='section_id12'></a>
# В нашем случае, нет отдельного файла с тестовой,тренировочной и валидной выборкой, поэтому мы их будем создавать сами. Поделим cначала на обучающую и промежуточную, а потом промежуточную поделим на валидную и тестовую.

# %%
target = df_ohe['Exited']
features = df_ohe.drop('Exited', axis=1)

# %%
features_train, features_inter, target_train, target_inter = train_test_split(
    features.copy(), 
    target.copy(), 
    test_size=0.4, 
    random_state=12345)

# %% [markdown]
# Теперь промежуточную поделим пополам

# %%
features_valid, features_test, target_valid, target_test = train_test_split(
    features_inter.copy(),
    target_inter.copy(),
    test_size=0.5,
    random_state=12345)

# %% [markdown]
# Тренировочная выборка у нас с такой размерностью

# %%
features_train.shape
# Out:
# (6000, 11)

# %% [markdown]
# Тестовая и валидная такая:

# %%
features_valid.shape
# Out:
# (2000, 11)

# %% [markdown]
# ### Масштабирование
# <a id='section_id13'></a>
# Стандартизируем численные признаки при помощи StandardScaler

# %%
numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']

scaler = StandardScaler()
scaler.fit(features_train[numeric])
features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric]  = scaler.transform(features_valid[numeric])
features_test[numeric]  = scaler.transform(features_test[numeric])

pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Краткий вывод по первому шагу.
# <a id='section_id1'></a>
#
# Ознакомившись с таблицей, мы увидели или сделали многое, в частности
# * Выявили, что есть пустоты по полю Tenure. Для более корректной последюущей работы мы заполнили их медианным значеним по столбцу;
# [Подробнее](#section_id10)
# * Явных дубликатов по полю нами обнаружено не было;
# * Воспользовавшись техников One-hot-encoding мы преобразовали категориальные признаки в численные. Также, чтобы не попасть в дамми-ловушку мы вызовом функции pd.get_dummies() c аргументом drop_first = True удалили первую колонку;
# [Подробнее](#section_id11)
# * В следствии того, что у нас только один файл(а не три), мы его честно поделили на три части. Сначала общую поделили на тестовую и промежуточную. Поделили в соотношении 40/60. Всё таки учебная выборка должна быть больше остальных. Далее промежуточную поделили пополам - на валидную и тестовую;
# [Подробнее](#section_id12)
# * Так как в наших данных присутствуют количественные признаки с разными разбросами значений мы решили их масштабировать применив стандартизацию данных.
# [Подробнее](#section_id13)

# %% [markdown]
# ## Исследование задачи
#
# [Сразу к выводу](#section_id2)

# %% [markdown]
# Так как в нашем случае, стоит задача на классификацию, то наш выбор будет ограничиваться вот такими моделями:

# %% [markdown]
# ![scheme.png](attachment:scheme.png)

# %%
df_ohe['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
df_ohe['Exited'].value_counts().plot(
    kind='bar',
    stacked=True,
    grid=True,
    color='indigo',
    width=0.9,
    figsize=(12,7)
    )
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='section_id21'></a>
# Как мы видим порядка 80 процентов данных по пользователям оставшимся, и только 20 ушедших, что хорошо для банка но не есть отлично для нас с точки зрения построяния модели. Протестируем на разных моделях.

# %% [markdown]
# ### Дерево решений в регрессии.
# <a id='section_id22'></a>

# %%
model_dt = DecisionTreeClassifier(random_state=12345) 
model_dt.fit(features_train,target_train) 
predictions_valid_dt = model_dt.predict(features_valid) 
accuracy_score(target_valid, predictions_valid_dt)
# Out:
# 0.7935

# %% [markdown]
# ### Случайный лес в регрессии.

# %%
model_rf = RandomForestClassifier(random_state=12345)
model_rf.fit(features_train, target_train) 
predictions_valid_rf = model_rf.predict(features_valid)
accuracy_score(target_valid, predictions_valid_rf)
# Out:
# 0.8585

# %% [markdown]
# ### Логистическая регрессия

# %%
model_lr = LogisticRegression(random_state=12345) 
model_lr.fit(features_train, target_train) 
model_lr.score(features_valid, target_valid)
# Out:
# 0.802

# %% [markdown]
# ### DummyClassifier
# <a id='section_id23'></a>
# Для проверки на адекватность модели используем DummyClassifier

# %%
dummy_clf1 = DummyClassifier(strategy="most_frequent", random_state=0)
dummy_clf1.fit(features_train, target_train)
dummy_clf1.score(features_valid, target_valid)
# Out:
# 0.791

# %% [markdown]
# При стратегии самых частых, точность недалека от дерева решений.

# %%
dummy_clf2 = DummyClassifier(strategy="uniform", random_state=0)
dummy_clf2.fit(features_train, target_train)
dummy_clf2.score(features_valid, target_valid)
# Out:
# 0.5055

# %% [markdown]
# Равномерный рандом, не самая лучшая стратегия.

# %%
dummy_clf3 = DummyClassifier(strategy="stratified", random_state=0)
dummy_clf3.fit(features_train, target_train)
dummy_clf3.score(features_valid, target_valid)
# Out:
# 0.6605

# %% [markdown]
# Cтратифицированный прогноз по группам даёт результат хуже используемых моделей.

# %%
dummy_clf4 = DummyClassifier(strategy="constant", random_state=0, constant = 1)
dummy_clf4.fit(features_train, target_train)
dummy_clf4.score(features_valid, target_valid)
# Out:
# 0.209

# %% [markdown]
# Всегда одно предсказание показало самый худший результат.

# %% [markdown]
# ### Матрица ошибок, плотность, точность, F1 score, roc_auc
# Лучшее значение accuracy мы получили на модели случайного леса в регрессии, рассчитаем необходимые величины для неё.

# %% [markdown]
# Рассчитаем матрицу решений

# %%
confusion_matrix(target_valid, predictions_valid_rf)
# Out:
# array([[1524,   58],
#        [ 225,  193]])

# %% [markdown]
# <a id='section_id24'></a>
# Рассчитаем плотность и точность

# %%
display(recall_score(target_valid, predictions_valid_rf))
display(precision_score(target_valid, predictions_valid_rf))
# Out:
# 0.46172248803827753
# 0.7689243027888446

# %%
model_rf = RandomForestClassifier(random_state=12345)
model_rf.fit(features_train, target_train) 
probabilities_valid_rf = model_rf.predict_proba(features_valid)
precision, recall, thresholds = precision_recall_curve(target_valid, probabilities_valid_rf[:, 1])

plt.figure(figsize=(6, 6))
plt.step(recall, precision, where='post')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Кривая Precision-Recall')
plt.show()

# %% [markdown]
# Неплохая точность, но полнота слабая.

# %% [markdown]
# Вычислим F1-меру
# <a id='section_id25'></a>

# %%
f1_score(target_valid, predictions_valid_rf)
# Out:
# 0.5769805680119582

# %% [markdown]
# Изобразим противостояние TPR против FPR на графике (кривой-ошибок).

# %%
probabilities_valid = model_rf.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]
auc_roc = roc_auc_score(target_valid,probabilities_one_valid)
auc_roc
# Out:
# 0.8406361337777266

# %%
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid) 
plt.figure()
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.color='indigo',
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.show()

# %% [markdown]
# ### Краткий вывод по второму шагу.
# <a id='section_id2'></a>
#
# * Рассмотрев распределение по признаку мы увидели дисбаланс в данных - порядка 1 к 4;
# [Подробнее](#section_id21)
# * Далее мы посчитали значение accuracy для 3 типов модели (Дерево решений/ Случайный лес/ Логистическая регрессия). По резлуьтатам лучшие показатели были у случайного леса;[Подробнее](#section_id22)
# * Далее мы решили проверить на адекватность модели ибо может тупой рандом или стратифицированный прогноз покажет не сильно отличающийся точностью прогноз, но оказалось, что почти все наши модели работают лучше чем DummyClassifier;[Подробнее](#section_id23)
# * Ранее мы выявиили что лучший результат показывает модель случайного леса, для неё мы решили рассчитать матрицу ошибок, плотность, точность и в завершение построить кривую ошибок.
# * Построив матрицу ошибок мы получили общее предсавление по неточностям нашей модели.
# * Перейдя к полноте и точности мы можем утверждать, что полнота в нашей модели достаточно слабая(0,46) - а это означает,что **модель плохо ищет положительные объекты**, причём точность находится на достаточно хорошем уровне (0,76).[Подробнее](#section_id24)
# * По отдельности полнота и точность не слишком информативны, в идеале необходимо иметь высокие значения обоих. Поэтому мы обратились к показателю f1 (среднегармоническое полноты и точности). Оно показало значение 0.57, то от чего мы будем отталкиваться и что мы будем стремиться увеличить (балансировкой, работой с выборкой, подбором гиперпараметров).[Подробнее](#section_id25)

# %% [markdown]
# ## Борьба с дисбалансом
#
# [Сразу к выводу](#section_id3)

# %% [markdown]
# Для борьбы с дисбалансом мы будем использовать три способа - взвешевание классов, уменьшение(в части положительных) и увеличение(в части отрицательных) выборки.

# %% [markdown]
# ### взвешивание классов
#
# <a id='section_id31'></a>

# %% [markdown]
# #### Дерево решений в регрессии.

# %%
model_dt = DecisionTreeClassifier(random_state=12345) 
model_dt.fit(features_train,target_train) 
predictions_valid_dt = model_dt.predict(features_valid) 

print('F1:',f1_score(target_valid, predictions_valid_dt))
probabilities_valid_dt = model_dt.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_dt))
# Out:
# F1: 0.5006045949214026
# ROC_AUC 0.6837644190927842

# %%
model_dt = DecisionTreeClassifier(random_state=12345,  class_weight='balanced') 
model_dt.fit(features_train,target_train) 
predictions_valid_dt = model_dt.predict(features_valid) 

print('F1:',f1_score(target_valid, predictions_valid_dt))
probabilities_valid_dt = model_dt.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_dt))
# Out:
# F1: 0.47469879518072294
# ROC_AUC 0.6676939734694742

# %% [markdown]
# Значения стали ниже, но не значительно.

# %% [markdown]
# #### Случайный лес в регрессии.

# %%
model_rf = RandomForestClassifier(random_state=12345)
model_rf.fit(features_train, target_train)
predictions_valid_rf = model_rf.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_rf))
probabilities_valid_rf = model_rf.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_rf))
# Out:
# F1: 0.5769805680119582
# ROC_AUC 0.8406361337777266

# %%
model_rf = RandomForestClassifier(random_state=12345,  class_weight='balanced')
model_rf.fit(features_train, target_train)
predictions_valid_rf = model_rf.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_rf))
probabilities_valid_rf = model_rf.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_rf))
# Out:
# F1: 0.5648148148148148
# ROC_AUC 0.8393847652115003

# %% [markdown]
# Значения стали ниже, но не значительно.

# %% [markdown]
# #### Логистическая регрессия

# %%
model_lr = LogisticRegression(random_state=12345) 
model_lr.fit(features_train, target_train) 
predictions_valid_lr = model_lr.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_lr))
probabilities_valid_lr = model_lr.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_lr))
# Out:
# F1: 0.33108108108108103
# ROC_AUC 0.7588057029137607

# %%
model_lr = LogisticRegression(random_state=12345,  class_weight='balanced') 
model_lr.fit(features_train, target_train) 
predictions_valid_lr = model_lr.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_lr))
probabilities_valid_lr = model_lr.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_lr))
# Out:
# F1: 0.4888507718696398
# ROC_AUC 0.7636750766699532

# %% [markdown]
# F1 вырос а ROC_AUC упал но незначительно.

# %% [markdown]
# ### Увеличение выборки

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    return shuffle(features_upsampled,target_upsampled, random_state=12345)
    
features_upsampled, target_upsampled = upsample(features_train, target_train, 4)

# %%
features_upsampled.shape
# Out:
# (9588, 11)

# %%
target_upsampled.value_counts()
# Out:
# 0    4804
# 1    4784
# Name: Exited, dtype: int64

# %%
target_upsampled.value_counts().plot(
    kind='bar',
    stacked=True,
    grid=True,
    color='indigo',
    width=0.9,
    figsize=(12,7)
    )
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='section_id32'></a>
# Соотношение улучшилось!

# %% [markdown]
# Проверим на моделях.

# %% [markdown]
# #### Дерево решений в регрессии.

# %%
model_dt = DecisionTreeClassifier(random_state=12345,  class_weight='balanced') 
model_dt.fit(features_upsampled,target_upsampled) 
predictions_valid_dt = model_dt.predict(features_valid) 

print('F1:',f1_score(target_valid, predictions_valid_dt))
probabilities_valid_dt = model_dt.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_dt))
# Out:
# F1: 0.47381546134663344
# ROC_AUC 0.6659579358694403

# %% [markdown]
# #### Случайный лес в регрессии.

# %%
model_rf = RandomForestClassifier(random_state=12345,  class_weight='balanced')
model_rf.fit(features_upsampled, target_upsampled)
predictions_valid_rf = model_rf.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_rf))
probabilities_valid_rf = model_rf.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_rf))
# Out:
# F1: 0.6050198150594451
# ROC_AUC 0.8422436320084201

# %% [markdown]
# <a id='section_id33'></a>
# Показатель F1 уже 60!

# %% [markdown]
# #### Логистическая регрессия

# %%
model_lr = LogisticRegression(random_state=12345,  class_weight='balanced') 
model_lr.fit(features_upsampled, target_upsampled) 
predictions_valid_lr = model_lr.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_lr))
probabilities_valid_lr = model_lr.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_lr))
# Out:
# F1: 0.4888507718696398
# ROC_AUC 0.7636312220615901

# %% [markdown]
# ### Уменьшение выборки

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
  
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train, 0.4)

# %%
features_downsampled.shape
# Out:
# (3118, 11)

# %%
target_downsampled.value_counts()
# Out:
# 0    1922
# 1    1196
# Name: Exited, dtype: int64

# %% [markdown]
# <a id='section_id34'></a>
# Соотношение уже лучше чем в изначальной выборке.

# %%
target_downsampled.value_counts().plot(
    kind='bar',
    stacked=True,
    grid=True,
    color='indigo',
    width=0.9,
    figsize=(12,7)
    )
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Дерево решений в регрессии.

# %%
model_dt = DecisionTreeClassifier(random_state=12345,  class_weight='balanced') 
model_dt.fit(features_downsampled,target_downsampled) 
predictions_valid_dt = model_dt.predict(features_valid) 

print('F1:',f1_score(target_valid, predictions_valid_dt))
probabilities_valid_dt = model_dt.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_dt))
# Out:
# F1: 0.48349514563106805
# ROC_AUC 0.6831186977903325

# %% [markdown]
# #### Случайный лес в регрессии.

# %%
model_rf = RandomForestClassifier(random_state=12345,  class_weight='balanced')
model_rf.fit(features_downsampled, target_downsampled)
predictions_valid_rf = model_rf.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_rf))
probabilities_valid_rf = model_rf.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_rf))
# Out:
# F1: 0.6143344709897611
# ROC_AUC 0.8413937599428982

# %% [markdown]
# <a id='section_id35'></a>
# Лучший показатель F1 уже за 60! И ROC_AUC увеличился!

# %% [markdown]
# #### Логистическая регрессия

# %%
model_lr = LogisticRegression(random_state=12345,  class_weight='balanced') 
model_lr.fit(features_downsampled, target_downsampled) 
predictions_valid_lr = model_lr.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_lr))
probabilities_valid_lr = model_lr.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_lr))
# Out:
# F1: 0.4918314703353396
# ROC_AUC 0.7640818659682189

# %% [markdown]
# ### Краткий вывод по третьему шагу.
#
# <a id='section_id3'></a>
#
# * На первом шаге мы __поигрались__ с взвешиванием классов. Мы посмотрели на то какое значение модель даёт без сбалансированого взвешивании классов и с. У всех моделей за исключением логистической регресии значение F1 и ROC_AUC падало (пускай и незначительно).
# [Подробнее](#section_id31)
# * Далее для того, чтобы объекты редкого класса стали не такими редкими в выборке мы прибегли к увеличению выборки. Написал функцию мы вновь посмотрели на соотношение классов и увидели, что оно изменилось с 1 к 4 в сторону 2 к 5 после чего вновь протестировали на новой апсемплиованной выборке нашу троицу моделей.
# [Подробнее](#section_id32)
# * В результате у если у моделей дерева и решений был виден рост и по f1 и roc_auc на 0.1, то по модели случайоно леса значение f1 достигло 0.60 а roc_auc 0.83 и это мы еще не подбирали гиперпараметры! [Подробнее](#section_id33)
# * Далее мы постарались объекты частого класса сделать не такими частыми в выборке прибегнув уменьшения выборки. Написав функцию и применив её к выборке мы получили распределение ну-почти равное. После чего мы протестировали на новой даунсэмплииованной выборке наши модели.
# [Подробнее](#section_id34)
# * В результате мы получили, что случайого леса показатели самые лучшие по сравнению с другими f1 0.61 пртив 0.48 и 0.49  и roc_auc 0.83 против 0.68 и 0.76 и вообще по всем моделям лучшие показатели получились именно при уменьшении выборки и использовании всешенных классов.
# [Подробнее](#section_id35)

# %% [markdown]
# ## Тестирование модели
# [Сразу к выводу](#section_id4)
#
# Прежде чем тестировать/учить наши модели на уменьшенной выборке и потом уже на тестовых данных мы для начала перейдем к подбору идеальных гиперпараметров.

# %% [markdown]
# #### Дерево решений в регрессии.
#
# Попробуем подобрать максимальную глубину.

# %% [markdown]
# <b>
# Попробуем использовать GreedSeacrhCV для дерева решений
# </b>

# %%
model = DecisionTreeClassifier(random_state=12345)
    

param_dict = {'max_depth': range(1, 10)}

grid = GridSearchCV(model, param_dict, cv = 5, scoring='f1', n_jobs = -1)

grid.fit(features_train, target_train)
grid.best_score_
# Out:
# 0.569923875807305

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=12345)

# %% [markdown]
# попробуем сами

# %%
for depth in range(1, 10):
    model = DecisionTreeClassifier(random_state=12345, max_depth = depth,  class_weight='balanced') # обучите модель с заданной глубиной дерева
    model.fit(features_downsampled, target_downsampled) # обучим модель
    predictions_valid = model.predict(features_valid) # получим предсказания модели
    result = accuracy_score(target_valid, predictions_valid) # посчитаем качество модели
    f1 = f1_score(target_valid , predictions_valid)
    print('max_depth =', depth, ':', result)
    print('f1_score =',f1)
    print()
# Out:
# max_depth = 1 : 0.7545
# f1_score = 0.4994903160040775
#
# max_depth = 2 : 0.765
# f1_score = 0.541015625
#
# max_depth = 3 : 0.784
# f1_score = 0.558282208588957
#
# max_depth = 4 : 0.681
# f1_score = 0.5129770992366411
#
# max_depth = 5 : 0.77
# f1_score = 0.5542635658914729
#
# max_depth = 6 : 0.7865
# f1_score = 0.5708542713567839
#
# max_depth = 7 : 0.773
# f1_score = 0.5708884688090737
#
# max_depth = 8 : 0.754
# f1_score = 0.5349716446124764
#
# max_depth = 9 : 0.735
# f1_score = 0.5216606498194946

# %% [markdown]
# <a id='section_id42'></a>
# Согласимся с GridSearchCV - 7 и в правду оптимально.

# %%
model_dt = DecisionTreeClassifier(random_state=12345,  max_depth=7) 
model_dt.fit(features_downsampled, target_downsampled) 
predictions_valid_dt = model_dt.predict(features_valid) 

print('F1:',f1_score(target_valid, predictions_valid_dt))
probabilities_valid_dt = model_dt.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_dt))
# Out:
# F1: 0.570801317233809
# ROC_AUC 0.796398175648292

# %% [markdown]
# #### Случайный лес в регрессии.
#
# Подберем гиперпараметры по максимальной глубине леса и количеству деревьев и минимальному количество примеров для разделения.

# %%
best_result = 0
best_est = 0
best_depth = 0
for est in range(10, 101, 5):
    for sample in range(2,5):
        for depth in range (1, 11):
            model = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth, min_samples_split = sample)
            model.fit(features_downsampled, target_downsampled) 
            predictions_valid = model.predict(features_valid)
            result = f1_score(target_valid , predictions_valid)
            if result > best_result:
                best_result = result
                best_est = est
                best_depth = depth
                best_split = sample


print("f1_score наилучшей модели на валидационной выборке:", best_result)
print("Количество деревьев:", best_est)
print("Максимальная глубина:", depth)
print("Минимальное количество примеров для разделения:",best_split)
# Out:
# f1_score наилучшей модели на валидационной выборке: 0.639080459770115
# Количество деревьев: 95
# Максимальная глубина: 10
# Минимальное количество примеров для разделения: 3

# %% [markdown]
# <b>
# Попробуем использовать для случайного леса RandomizedSearchCV
# </b>

# %%
model = RandomForestClassifier(random_state=12345)
    

param_dict = {'max_depth': range(1, 10),
             'n_estimators': range(10, 101, 5),
             'min_samples_split': range(2,5)}

grid = RandomizedSearchCV(model, param_dict, cv = 5, scoring='f1', n_jobs = -1)

#grid.fit(features_train, target_train)
grid.fit(features_downsampled, target_downsampled)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=12345),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': range(1, 10),
#                                         'min_samples_split': range(2, 5),
#                                         'n_estimators': range(10, 101, 5)},
#                    scoring='f1')

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=95, random_state=12345)

# %%
model_rf = RandomForestClassifier(random_state=12345,  n_estimators=40 , max_depth=9)
model_rf.fit(features_downsampled, target_downsampled)
#predictions_valid_rf = model_rf.predict(features_test)
predictions_valid_rf = model_rf.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_rf))
#probabilities_valid_rf = model_rf.predict_proba(features_test)[:, 1]
probabilities_valid_rf = model_rf.predict_proba(features_valid)[:, 1]
#print("ROC_AUC", roc_auc_score(target_test, probabilities_valid_dt))
print("ROC_AUC", roc_auc_score(target_valid, predictions_valid_rf))
# Out:
# F1: 0.6137931034482759
# ROC_AUC 0.7609076996594463

# %%
model_rf = RandomForestClassifier(random_state=12345,  n_estimators=95 , max_depth=10, min_samples_split = 3)
model_rf.fit(features_downsampled, target_downsampled)
predictions_valid_rf = model_rf.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_rf))
probabilities_valid_rf = model_rf.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_rf))
# Out:
# F1: 0.639080459770115
# ROC_AUC 0.8467840962018885

# %% [markdown]
# <a id='section_id44'></a>
# На данный момент лучший показатель F1.

# %% [markdown]
# #### Логистическая регрессия

# %%
model_lr = LogisticRegression(random_state=12345,  solver='liblinear') 
model_lr.fit(features_downsampled, target_downsampled) 
predictions_valid_lr = model_lr.predict(features_valid)

print('F1:',f1_score(target_valid, predictions_valid_lr))
probabilities_valid_lr = model_lr.predict_proba(features_valid)[:, 1]
print("ROC_AUC", roc_auc_score(target_valid, probabilities_valid_lr))
# Out:
# F1: 0.504875406283857
# ROC_AUC 0.7625877848281201

# %% [markdown]
# <a id='section_id43'></a>

# %% [markdown]
# #### Проверяем лучшую модель
#
# Модель с лучшими показателями была случайный лес, с гиперпараметрами что мы нашли сами, попробуем её на бою.

# %%
model_rf = RandomForestClassifier(random_state=12345,  n_estimators=95 , max_depth=10, min_samples_split = 3)
model_rf.fit(features_downsampled, target_downsampled)
predictions_valid_rf = model_rf.predict(features_test)

print('F1:',f1_score(target_test, predictions_valid_rf))
probabilities_valid_rf = model_rf.predict_proba(features_test)[:, 1]
print("ROC_AUC", roc_auc_score(target_test, probabilities_valid_rf))
# Out:
# F1: 0.5995423340961099
# ROC_AUC 0.8526378751287343

# %% [markdown]
# ROC_AUC отличный, а вот F1 средний. Попробуем ту же модель, но с параметрами RandomizedSearchCV

# %%
model_rf = RandomForestClassifier(random_state=12345,  n_estimators=40 , max_depth=9)
model_rf.fit(features_downsampled, target_downsampled)
predictions_valid_rf = model_rf.predict(features_test)

print('F1:',f1_score(target_test, predictions_valid_rf))
probabilities_valid_rf = model_rf.predict_proba(features_test)[:, 1]
print("ROC_AUC", roc_auc_score(target_test, probabilities_valid_rf))
# Out:
# F1: 0.5937859608745686
# ROC_AUC 0.8468678746340345

# %% [markdown]
# Всё таки руками подбирать гиперпараметры надежнее.

# %% [markdown]
# ### Краткий вывод по четвертому шагу.
#
# <a id='section_id4'></a>
#
# * Прежде чем приступить к тестированию модели мы определили оптимальное значение гиперпараметров для моделей, попытались сами и при помощи RandomizedSearchCV и GreedSeacrhCV.
# * По итогу для *Дерева решений* итоговые значения оказались **F1 = 0.57**, **Roc_auc= 0.81**
# [Подробнее](#section_id42)
# * Для *Логистической регрессии* значния оказались **F1 = 0.44**, **Roc_auc= 0.74**
# [Подробнее](#section_id43)
# * Для *Случайного леса* значения оказались самыми лучшими в исследовании - **F1 = 0.60**, **Roc_auc= 0.81**
# [Подробнее](#section_id44)
